# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
np.random.seed(100)

N = 100
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("X vs Y")
plt.scatter(x, y, c=colors, alpha=0.5)
plt.show()

# %%
formula=("C,H,N,O")
print(formula)
# Out:
# C,H,N,O

# %%
C=12.0107
H=1.00794
N=14.0067
O=15.999 
PM=([C*H*N*O])
print(PM)
# Out:
# [2712.8867547354507]

# %%
A=3,52
B=-2,85
C=5,16
x=[0.1,1]
y=A+10**(x)*B+C*x**2/2
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-a3de09137a59> in <module>()
#       3 C=5,16
#       4 x=[0.1,1]
# ----> 5 y=A+10**(x)*B+C*x*2/2
#       6 plt.show()
#
# TypeError: unsupported operand type(s) for ** or pow(): 'int' and 'list'

# %%
x=0.1
x=0.9
Ca=1,0
Cb=0,1
pka=4,72
pH=pka+10**(Ca-x/Cb+x)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-e808f5a2f0fe> in <module>()
#       4 Cb=0,1
#       5 pka=4,72
# ----> 6 pH=pka+10**(Ca-x/Cb+x)
#       7 plt.show()
#
# TypeError: unsupported operand type(s) for /: 'float' and 'tuple'
